# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import seaborn as sns
from scipy.stats import linregress

# Study data files
campaign = "ETL_Mini_Project_EElizondo_JPrice_AJyles/campaign.csv"
subcat = "ETL_Mini_Project_EElizondo_JPrice_AJyles/subcategory.csv"

# Read in csv files
campaign_data = pd.read_csv(campaign)
subcat_data = pd.read_csv(subcat)

# Combine the data into a single DataFrame
merged_df = pd.merge(campaign_data, subcat_data, how="left", on=["subcategory_id", "subcategory_id"])

# Display the dataframe
merged_df.head()
# Out:
#    cf_id  contact_id                 company_name  \
# 0    147        4661   Baldwin, Riley and Jackson
# 1   1621        3765                     Odom Inc
# 2   1812        4187   Melton, Robinson and Fritz
# 3   2156        4941  Mcdonald, Gonzalez and Ross
# 4   1365        2199                Larson-Little
#
#                                       descrition      goal   pledged  \
# 0           Pre-emptive tertiary standardization     100.0       0.0
# 1               Managed bottom-line architecture    1400.0   14560.0
# 2   Function-based leadingedge pricing structure  108400.0  142523.0
# 3  Vision-oriented fresh-thinking conglomeration    4200.0    2477.0
# 4                      Proactive foreground core    7600.0    5265.0
#
#       outcome  backers_count country currency        launched_date  \
# 0      failed              0      CA      CAD  2020-02-13 06:00:00
# 1  successful            158      US      USD  2021-01-25 06:00:00
# ...

# %%
merged_df_sorted = merged_df.sort_values(ascending=False, by='pledged')
merged_df_sorted.head()
# Out:
#      cf_id  contact_id          company_name  \
# 208    225        3411           Jackson Inc
# 335   3176        1791         Jordan-Acosta
# 703    195        3041           Perez Group
# 487   3172        3903         Smith-Wallace
# 427   2523        3181  Hicks, Wall and Webb
#
#                              descrition      goal   pledged     outcome  \
# 208  Mandatory multi-tasking encryption  196900.0  199110.0  successful
# 335               Operative uniform hub  173800.0  198628.0  successful
# 703         Cross-platform tertiary hub   63400.0  197728.0  successful
# 487           Monitored 24/7 time-frame  110300.0  197024.0  successful
# 427          Managed discrete framework  174500.0  197018.0  successful
#
#      backers_count country currency        launched_date             end_date  \
# 208           2053      US      USD  2020-12-07 06:00:00  2021-08-21 05:00:00
# 335           2283      US      USD  2020-02-27 06:00:00  2021-02-12 06:00:00
# ...

# %%
x = merged_df_sorted['subcategory']
y = merged_df_sorted['pledged']


plt.figure(figsize=(8,6))
plt.barh(x, y, color = "#1a759f")

# Plot customization
plt.ylabel("Subcategory", fontsize=12, fontstyle="italic")
plt.xlabel("Pledged (U.S. Dollars)", fontsize=12, fontstyle="italic")
plt.title("Subcategory Ranked By Pledged Amound", fontsize=16)
plt.grid(axis="x", color="lightgrey", linestyle="--", alpha=0.7)

plt.show()
